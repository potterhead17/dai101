# %%
import pandas as pd

# %%
data=pd.read_csv('project1_df.csv')

# %%
data.head()
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.5+ MB

# %%
# Checking for missing values and data types
missing_values = data.isnull().sum()
data_types = data.dtypes
data['Purchase Date'] = pd.to_datetime(data['Purchase Date'], format='%d/%m/%Y %H:%M:%S')
summary_stats = data.describe()

# Display missing values, data types, and summary statistics
print("Missing Values:\n", missing_values)
print("\nData Types:\n", data_types)
print("\nSummary Statistics:\n", summary_stats)
# Out:
# Missing Values:
#  CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64
#
# Data Types:
#  CID                        int64
# TID                        int64
# Gender                    object
# Age Group                 object
# Purchase Date             object
# Product Category          object
# Discount Availed          object
# Discount Name             object
# Discount Amount (INR)    float64
# Gross Amount             float64
# Net Amount               float64
# Purchase Method           object
# Location                  object
# dtype: object
#
# Summary Statistics:
# ...

# %%
### AS WE CAN SEE THAT THERE ARE ALMOST NO EMPTY TABLES SO WE CAN EASILY FURTHER PROCESS THE DATA

# %%
plt.figure(figsize=(10,6))

# %%
# UNIVARIATE ANALYSIS

# %%
# Gender Distribution as a Pie Chart
plt.figure(figsize=(8, 6))
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2"))
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %%
#NUMERICAL DATA
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histograms for numerical variables
numerical_columns = ['Discount Amount (INR)', 'Gross Amount', 'Net Amount']
df[numerical_columns].hist(bins=20, figsize=(10, 6), layout=(2, 2))
plt.suptitle('Histograms for Numerical Variables', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Boxplots to check for outliers in numerical variables
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numerical_columns])
plt.title('Boxplots for Numerical Variables')
plt.show()

# %%
# Correlation Heatmap for Numerical Variables
numerical_columns = ['Discount Amount (INR)', 'Gross Amount', 'Net Amount']
plt.figure(figsize=(8, 6))
correlation_matrix = df[numerical_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap for Numerical Variables')
plt.show()

# Scatter Plot of Discount Amount vs. Net Amount by Gender
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Discount Amount (INR)', y='Net Amount', hue='Gender', alpha=0.7, palette='Set2')
plt.title('Scatter Plot of Discount Amount vs. Net Amount by Gender')
plt.xlabel('Discount Amount (INR)')
plt.ylabel('Net Amount')
plt.show()

# %%
# Summary statistics for numerical variables
df[numerical_columns].describe()
# Out:
#        Discount Amount (INR)  Gross Amount    Net Amount
# count           55000.000000  55000.000000  55000.000000
# mean              136.986796   3012.936606   2875.949810
# std               165.375502   1718.431066   1726.127778
# min                 0.000000    136.454325   -351.119775
# 25%                 0.000000   1562.111325   1429.551863
# 50%                 0.000000   2954.266150   2814.910875
# 75%               274.115000   4342.221675   4211.407838
# max               500.000000   8394.825600   8394.825600

# %%
## This shows that very in Discount Amount very few people were able to get high discount and mostly got either low or no discount

## The Gross Amount and Net Amount distributions are slightly skewed to the right, indicating that most transactions have lower total amounts, but there are some high-value transactions.

# %%
## CATEGORICAL DATA

categorical_columns = ['Gender', 'Age Group', 'Product Category', 'Discount Availed']

plt.figure(figsize=(12, 8))

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=column, data=df, hue=column, palette='Set2', legend=False)
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# Frequency distribution for categorical variables
df[categorical_columns].apply(pd.Series.value_counts)
# Out:
#                     Gender  Age Group  Product Category  Discount Availed
# 18-25                  NaN    16431.0               NaN               NaN
# 25-45                  NaN    22010.0               NaN               NaN
# 45-60                  NaN    11104.0               NaN               NaN
# 60 and above           NaN     2684.0               NaN               NaN
# Beauty and Health      NaN        NaN            8332.0               NaN
# Books                  NaN        NaN            2762.0               NaN
# Clothing               NaN        NaN           10968.0               NaN
# Electronics            NaN        NaN           16574.0               NaN
# Female             18454.0        NaN               NaN               NaN
# Home & Kitchen         NaN        NaN            5489.0               NaN
# Male               18096.0        NaN               NaN               NaN
# No                     NaN        NaN               NaN           27585.0
# ...

# %%
## Gender: The dataset is balanced across genders, with nearly equal numbers of male, female, and others

## Age Group: The majority of the customers are between 25-45 years old (22,010), followed by the 18-25 age group (16,431).

## Product Category: The most frequently purchased product categories are Electronics and Clothing, with categories like Books and Toys & Games being less common.

## Discount Availed: The customers are evenly split between those who availed discounts and those who didn't.

# %%
# Multivariate Analysis

# %%
# Boxplot to analyze the relationship between Age Group and Gross Amount
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age Group', y='Gross Amount', data=df,hue=column, palette='Set3',legend=False)
plt.title('Gross Amount across Age Groups')
plt.show()

# %%
# Boxplot to analyze the relationship between Gender and Net Amount
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Net Amount', data=df,hue=column,palette='Set2',legend=False)
plt.title('Net Amount across Genders')
plt.show()

# %%
# Bar plot to see the influence of Discount Availed on Net Amount
plt.figure(figsize=(10, 6))
sns.barplot(x='Discount Availed', y='Net Amount', data=df,hue=column,legend=False,palette='Set1')
plt.title('Impact of Discount Availed on Net Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Purchase Method', palette='Set2',hue=column)
plt.title('Count of Purchases by Purchase Method')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Product Category', hue='Gender', palette='Set2')
plt.title('Count of Purchases by Product Category and Gender')
plt.xticks(rotation=45)
plt.show()

# %%
## HERE WE CAN SEE THAT MOST OF THE PURCHASES WERE DONE USING CREDIT CARD AND IN EVERY PURCHASE METHOD MOSTLY 50% OF THE PEOPLE GOT THE DISCOUNT AND 50% DIDNT

## EACH GENDER HAD ALMOST AN EQUAL PERCENTAGE OF BUYING THE GOODS

## ELECTRONICS IS THE HIGHEST BUYING PRODUCT WITH ALMOST EQUAL PERCENTAGE FROM EACH GENDER

# %%
## HERE IS THE CORELATION MATRIX

# %%
from sklearn.preprocessing import LabelEncoder

# Copy the data to avoid altering the original dataset
encoded_data = data.copy()

# Step 1: Encode categorical columns
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_cols = ['Gender', 'Age Group', 'Product Category', 'Purchase Method', 'Discount Availed']

# Apply label encoding to each categorical column
for col in categorical_cols:
    encoded_data[col] = label_encoder.fit_transform(encoded_data[col])

# Step 2: Drop remaining non-numeric columns like 'Purchase Date', 'Location', and 'Discount Name'
encoded_data = encoded_data.drop(columns=['Purchase Date', 'Location', 'Discount Name'])

# Step 3: Recalculate the correlation matrix
correlation_matrix_expanded = encoded_data.corr()

# Step 4: Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix_expanded, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Expanded Correlation Matrix (with Encoded Categorical Fields)')
plt.show()

# %%
### From this we can see that their is a very high correlation between discount amount and discount availed
### Else the correlation is very less between each other

# %%
git init
# Out:
#   Cell In[2], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
